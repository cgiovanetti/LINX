# %%
# %load_ext autoreload
# %autoreload
import numpy as np
import jax.numpy as jnp
import jax
from jax import jit, vmap
import sys

sys.path.append("../")
import linx.const as const 
from linx.nuclear import NuclearRates
from linx.background import BackgroundModel
from linx.abundances import AbundanceModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       7 import sys
#       8
#       9 sys.path.append("../")
#      10 import linx.const as const
# ---> 11 from linx.nuclear import NuclearRates
#      12 from linx.background import BackgroundModel
#      13 from linx.abundances import AbundanceModel
#
# File ~\LINX-original\linx\..\linx\nuclear.py:2
#       1 import jax.numpy as jnp
# ----> 2 import equinox as eqx
#       3 import interpax
#       5 import linx.const as const
#
# ModuleNotFoundError: No module named 'equinox'
