# %%
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload
import numpy as np

import linx.const as const 
from linx.nuclear import NuclearRates
from linx.background import BackgroundModel
from linx.abundances import AbundanceModel
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       3 get_ipython().run_line_magic('autoreload', '')
#       4 import numpy as np
# ----> 6 import linx.const as const
#       7 from linx.nuclear import NuclearRates
#       8 from linx.background import BackgroundModel
#
# File ~\LINX-original\linx\const.py:1
# ----> 1 import jax
#       2 import jax.numpy as jnp
#       3 jax.config.update("jax_enable_x64", True) # need this to enable float64
#
# ModuleNotFoundError: No module named 'jax'
